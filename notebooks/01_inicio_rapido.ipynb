# %% [markdown]
# # 🗺️ Inicio Rápido con Leafmap
#
# Este notebook muestra cómo crear mapas interactivos de Córdoba usando Leafmap.
#
# **Contenido:**
# - Crear un mapa centrado en Córdoba
# - Cargar departamentos desde GeoJSON
# - Agregar capas de puntos (localidades)

# %%
import leafmap.foliumap as leafmap
import pandas as pd
import geopandas as gpd

# %%
# Crear mapa centrado en Córdoba
m = leafmap.Map(center=[-31.4201, -64.1888], zoom=7)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0035a883ebd956f29479b344918ab775 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0035a883ebd956f29479b344918ab775&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0035a883ebd956f29479b344918ab775 = L.map(
#                 &quot;map_0035a883ebd956f29479b344918ab775&quot;,
#                 {
#                     center: [-31.4201, -64.1888],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0035a883ebd956f29479b344918ab775);
#
#
#
#
#
#             var tile_layer_dbf36b3a067a70e038938eb1329d6f77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbf36b3a067a70e038938eb1329d6f77.addTo(map_0035a883ebd956f29479b344918ab775);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_0035a883ebd956f29479b344918ab775);
#
#
#             map_0035a883ebd956f29479b344918ab775.fitBounds(
#                 [[-31.4201, -64.1888], [-31.4201, -64.1888]],
#                 {&quot;maxZoom&quot;: 7}
#             );
#
#
#             var layer_control_8cb636ee1b063e998fcda46397ab6ac2_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_dbf36b3a067a70e038938eb1329d6f77,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_8cb636ee1b063e998fcda46397ab6ac2 = L.control.layers(
#                 layer_control_8cb636ee1b063e998fcda46397ab6ac2_layers.base_layers,
#                 layer_control_8cb636ee1b063e998fcda46397ab6ac2_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_0035a883ebd956f29479b344918ab775);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" width="100%" height="600"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# Cargar departamentos desde GeoJSON
departamentos = gpd.read_file('/home/jovyan/data/cordoba/departamentos.geojson')
m.add_gdf(departamentos, layer_name='Departamentos', style={'color': 'blue', 'weight': 2, 'fillOpacity': 0.1})
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0035a883ebd956f29479b344918ab775 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0035a883ebd956f29479b344918ab775&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0035a883ebd956f29479b344918ab775 = L.map(
#                 &quot;map_0035a883ebd956f29479b344918ab775&quot;,
#                 {
#                     center: [-31.4201, -64.1888],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0035a883ebd956f29479b344918ab775);
#
#
#
#
#
#             var tile_layer_dbf36b3a067a70e038938eb1329d6f77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbf36b3a067a70e038938eb1329d6f77.addTo(map_0035a883ebd956f29479b344918ab775);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_0035a883ebd956f29479b344918ab775);
#
#
#             map_0035a883ebd956f29479b344918ab775.fitBounds(
#                 [[-31.4201, -64.1888], [-31.4201, -64.1888]],
#                 {&quot;maxZoom&quot;: 7}
#             );
#
#
#             var layer_control_8cb636ee1b063e998fcda46397ab6ac2_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_dbf36b3a067a70e038938eb1329d6f77,
#                 },
#                 overlays :  {
#                     &quot;Departamentos&quot; : geo_json_98e7008515634b201e223ec7b54c4d99,
#                 },
#             };
#             let layer_control_8cb636ee1b063e998fcda46397ab6ac2 = L.control.layers(
#                 layer_control_8cb636ee1b063e998fcda46397ab6ac2_layers.base_layers,
#                 layer_control_8cb636ee1b063e998fcda46397ab6ac2_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_0035a883ebd956f29479b344918ab775);
#
#
#
#             tile_layer_dbf36b3a067a70e038938eb1329d6f77.addTo(map_0035a883ebd956f29479b344918ab775);
#
#
#         function geo_json_98e7008515634b201e223ec7b54c4d99_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_98e7008515634b201e223ec7b54c4d99_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0, &quot;weight&quot;: 4};
#             }
#         }
#
#         function geo_json_98e7008515634b201e223ec7b54c4d99_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_98e7008515634b201e223ec7b54c4d99.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_98e7008515634b201e223ec7b54c4d99_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_98e7008515634b201e223ec7b54c4d99 = L.geoJson(null, {
#                 onEachFeature: geo_json_98e7008515634b201e223ec7b54c4d99_onEachFeature,
#
#                 style: geo_json_98e7008515634b201e223ec7b54c4d99_styler,
#             ...{
# }
#         });
#
#         function geo_json_98e7008515634b201e223ec7b54c4d99_add (data) {
#             geo_json_98e7008515634b201e223ec7b54c4d99
#                 .add

# %%
# Cargar localidades desde CSV
localidades = pd.read_csv('/home/jovyan/data/cordoba/localidades.csv')
print(f"Localidades cargadas: {len(localidades)}")
localidades.head()
# Out:
# Localidades cargadas: 55
#      codigo         nombre        departamento  latitud  longitud  poblacion
# 0  14014010        Córdoba             Capital -31.4201  -64.1888    1330023
# 1  14098010     Río Cuarto          Río Cuarto -33.1307  -64.3499     158298
# 2  14126010    Villa María  General San Martín -32.4074  -63.2429      80006
# 3  14021010  San Francisco           San Justo -31.4281  -62.0828      62211
# 4  14028010     Carlos Paz             Punilla -31.4241  -64.4979      62750

# %% [markdown]
# ---
#
# ## 📚 Próximos pasos
#
# - **02_mapa_calor.ipynb**: Crear mapas de calor con indicadores
# - **03_analisis_por_zona.ipynb**: Análisis por departamento y región sanitaria
# - **05_cruce_datos.ipynb**: Análisis de datos geográficos

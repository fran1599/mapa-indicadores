# %% [markdown]
# # 🗺️ Análisis por Zona
#
# Este notebook muestra cómo analizar indicadores por departamento y región sanitaria.
#
# **Contenido:**
# - Cargar indicadores, departamentos y regiones sanitarias
# - Agrupar indicadores por localidad
# - Crear mapas con departamentos y puntos proporcionales
# - Visualizar regiones sanitarias

# %%
import leafmap.foliumap as leafmap
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
# Cargar datos
indicadores = pd.read_csv('/home/jovyan/data/ejemplo_indicadores.csv')
departamentos = gpd.read_file('/home/jovyan/data/cordoba/departamentos.geojson')
regiones = gpd.read_file('/home/jovyan/data/cordoba/regiones_sanitarias.geojson')

# %%
# Agrupar indicadores por localidad
resumen = indicadores.groupby('localidad').agg({
    'valor': 'sum',
    'latitud': 'first',
    'longitud': 'first'
}).reset_index()
print(resumen)
# Out:
#         localidad  valor  latitud  longitud
# 0     Alta Gracia     68 -31.6596  -64.4298
# 1      Bell Ville     68 -32.6277  -62.6889
# 2      Carlos Paz     80 -31.4241  -64.4979
# 3         Cosquín     39 -31.2436  -64.4664
# 4    Cruz del Eje     55 -30.7269  -64.8063
# 5         Córdoba    864 -31.4201  -64.1888
# 6      Deán Funes     30 -30.4268  -64.3507
# 7     Jesús María     68 -30.9816  -64.0953
# 8       La Calera     46 -31.3439  -64.3347
# 9      La Carlota     11 -33.4178  -63.2967
# 10      Laboulaye     25 -34.1269  -63.3911
# 11  Marcos Juárez     72 -32.6908  -62.1057
# 12     Río Cuarto    272 -33.1307  -64.3499
# 13    Río Tercero     64 -32.1737  -64.1144
# 14  San Francisco     98 -31.4281  -62.0828
# 15  Villa Dolores     52 -31.9442  -65.1890
# 16    Villa María    302 -32.4074  -63.2429

# %%
# Mapa con departamentos y puntos proporcionales
m = leafmap.Map(center=[-31.4201, -64.1888], zoom=7)
m.add_gdf(departamentos, layer_name='Departamentos', style={'color': 'gray', 'weight': 1, 'fillOpacity': 0.1})
m.add_heatmap(data=resumen, latitude='latitud', longitude='longitud', value='valor', name='Total por localidad', radius=40)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ea2b9a0548242e5d6c9b97f7e692f70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ea2b9a0548242e5d6c9b97f7e692f70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ea2b9a0548242e5d6c9b97f7e692f70 = L.map(
#                 &quot;map_5ea2b9a0548242e5d6c9b97f7e692f70&quot;,
#                 {
#                     center: [-31.4201, -64.1888],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5ea2b9a0548242e5d6c9b97f7e692f70);
#
#
#
#
#
#             var tile_layer_d952d46f6a23829253703007f4582964 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d952d46f6a23829253703007f4582964.addTo(map_5ea2b9a0548242e5d6c9b97f7e692f70);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_5ea2b9a0548242e5d6c9b97f7e692f70);
#
#
#             map_5ea2b9a0548242e5d6c9b97f7e692f70.fitBounds(
#                 [[-31.4201, -64.1888], [-31.4201, -64.1888]],
#                 {&quot;maxZoom&quot;: 7}
#             );
#
#
#         function geo_json_aa1d5028183c8fd0fe33b97daee5bf72_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.1, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_aa1d5028183c8fd0fe33b97daee5bf72_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_aa1d5028183c8fd0fe33b97daee5bf72_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_aa1d5028183c8fd0fe33b97daee5bf72.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_aa1d5028183c8fd0fe33b97daee5bf72_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_aa1d5028183c8fd0fe33b97daee5bf72 = L.geoJson(null, {
#                 onEachFeature: geo_json_aa1d5028183c8fd0fe33b97daee5bf72_onEachFeature,
#
#                 style: geo_json_aa1d5028183c8fd0fe33b97daee5bf72_styler,
#             ...{
# }
#         });
#
#         function geo_json_aa1d5028183c8fd0fe33b97daee5bf72_add (data) {
#             geo_json_aa1d5028183c8fd0fe33b97daee5bf72
#                 .addData(data);
#         }
#             geo_json_aa1d5028183c8fd0fe33b97daee5bf72_add({&quot;bbox&quot;: [-65.4, -34.8, -61.8, -29.5], &quot;features&quot;: [{&quot;bbox&quot;: [-64.3, -31.5, -64.1, -31.3], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-64.3, -31.3], [-64.3, -31.5], [-64.1, -31.5], [-64.1, -31.3], [-64.3, -31.3]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;cabecera&quot;: &quot;C\u00f3rdoba&quot;, &quot;codigo&quot;: &quot;14007&quot;, &quot;codigo_provincia&quot;: &quot;AR-X&quot;, &quot;nombre&quot;: &quot;Capital&quot;, &quot;poblacion&quot;: 1330023, &quot;provincia&quot;: &quot;C\u00f3rdoba&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-64.8, -33.5, -63.8, -32.8], &quot;

# %%
def limpiar_departamentos(x):
    if isinstance(x, np.ndarray):
        x = x.tolist()
    if isinstance(x, list):
        return ", ".join(x)
    return str(x)

regiones["departamentos"] = regiones["departamentos"].apply(limpiar_departamentos)

# Mapa con regiones sanitarias
m2 = leafmap.Map(center=[-31.4201, -64.1888], zoom=7)
m2.add_gdf(regiones, layer_name='Regiones Sanitarias', style={'color': 'green', 'weight': 2, 'fillOpacity': 0.2})
m2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82c86200b836106660ec10edcdf10fd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82c86200b836106660ec10edcdf10fd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82c86200b836106660ec10edcdf10fd8 = L.map(
#                 &quot;map_82c86200b836106660ec10edcdf10fd8&quot;,
#                 {
#                     center: [-31.4201, -64.1888],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_82c86200b836106660ec10edcdf10fd8);
#
#
#
#
#
#             var tile_layer_4c98e7561ee9af18652afbcf38d6e3ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4c98e7561ee9af18652afbcf38d6e3ca.addTo(map_82c86200b836106660ec10edcdf10fd8);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_82c86200b836106660ec10edcdf10fd8);
#
#
#             map_82c86200b836106660ec10edcdf10fd8.fitBounds(
#                 [[-31.4201, -64.1888], [-31.4201, -64.1888]],
#                 {&quot;maxZoom&quot;: 7}
#             );
#
#
#         function geo_json_6d21874984c6c3c63c4f2b2e8179c933_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6d21874984c6c3c63c4f2b2e8179c933_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0, &quot;weight&quot;: 4};
#             }
#         }
#
#         function geo_json_6d21874984c6c3c63c4f2b2e8179c933_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6d21874984c6c3c63c4f2b2e8179c933.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6d21874984c6c3c63c4f2b2e8179c933_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6d21874984c6c3c63c4f2b2e8179c933 = L.geoJson(null, {
#                 onEachFeature: geo_json_6d21874984c6c3c63c4f2b2e8179c933_onEachFeature,
#
#                 style: geo_json_6d21874984c6c3c63c4f2b2e8179c933_styler,
#             ...{
# }
#         });
#
#         function geo_json_6d21874984c6c3c63c4f2b2e8179c933_add (data) {
#             geo_json_6d21874984c6c3c63c4f2b2e8179c933
#                 .addData(data);
#         }
#             geo_json_6d21874984c6c3c63c4f2b2e8179c933_add({&quot;bbox&quot;: [-65.5, -34.85, -61.75, -29.45], &quot;features&quot;: [{&quot;bbox&quot;: [-64.35, -31.55, -64.05, -31.25], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-64.35, -31.25], [-64.35, -31.55], [-64.05, -31.55], [-64.05, -31.25], [-64.35, -31.25]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;cabecera&quot;: &quot;C\u00f3rdoba&quot;, &quot;codigo&quot;: &quot;RS01&quot;, &quot;departamentos&quot;: &quot;Capital&quot;, &quot;nombre&quot;: &quot;Regi\u00f3n Sanitaria Capital&quot;, &quot;numero&quot;: 1, &quot;poblacion&quot;: 1330023}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-64.75, -31.45, -64.25, -30.75], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-64.75, -30.75], [-64.75, -31.45], [-64.25, -31.45], [-64.25, -30.75], [-64.75, -30.7

# %% [markdown]
# ---
#
# ## 📚 Próximos pasos
#
# - **05_cruce_datos.ipynb**: Análisis cruzando datos censales
